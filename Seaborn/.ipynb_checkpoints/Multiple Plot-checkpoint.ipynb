# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = sns.load_dataset("tips")
a = sns.FacetGrid(data, col = "time", height = 2, hue = "sex")
a.map(sns.stripplot, "day", "tip")
plt.show()
# Out:
# C:\Users\Rakibul Hassan\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the stripplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
