# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = {"Days":[1,2,3,4,5],
       "NOP": [50,40,60,30,44]}
df = pd.DataFrame(data)
# print(df)
sns.lineplot(data=df, x = "Days", y = "NOP")
plt.show()

# %%
data = pd.read_excel("ESD.xlsx")
# print(data)
"""sns.lineplot(data = data,x="Business Unit", y = "Age", hue = "Ethnicity",style="Gender")  # style on line basis and hue is on color basis"""
color = sns.color_palette("GnBu")
sns.lineplot(data = data,x="Business Unit", y = "Age", hue="Ethnicity",palette = color) 
plt.show()
# Out:
# C:\Users\Rakibul Hassan\AppData\Local\Temp\ipykernel_1552\3019061375.py:5: UserWarning: The palette list has more values (6) than needed (4), which may not be intended.
#   sns.lineplot(data = data,x="Business Unit", y = "Age", hue="Ethnicity",palette = color)
