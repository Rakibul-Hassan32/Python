# %%
import matplotlib.pyplot as plt
import seaborn as sns

data = sns.load_dataset('tips')
# print(data)
sns.histplot(data, x = "day", hue = 'sex', kde = True)  # line formation = kde
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data = sns.load_dataset('titanic')
# print(data)
"""sns.histplot(data = data, x = "age", hue = 'who', kde = True, discrete = True)  # no gaps = discrete"""
sns.histplot(data = data, x = "age", hue = 'who', kde = True, bins = 35)
plt.show()
